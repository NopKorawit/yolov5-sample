# %% [markdown]
# # Check CUDA

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5  1aea74c Python-3.9.13 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Setup complete  (8 CPUs, 19.8 GB RAM, 393.4/753.9 GB disk)

# %% [markdown]
# ## W&B login

# %%
import wandb; wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: korawit. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Train model

# %%
# in cmd
# !python train.py --img 416 --batch 16 --workers 1 --epochs 50 --data Dogs.yaml --weights yolov5s_dogs.pt

# %% [markdown]
# # Test model

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source DataSet/Bangkaew-Shiba_Test
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=DataSet/Bangkaew-Shiba_Test, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  1aea74c Python-3.9.13 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 E:\CPE\Programing\yolov5-sample\DataSet\Bangkaew-Shiba_Test\Sb001.png: 448x640 1 Shiba_Inu, 15.0ms
# image 2/8 E:\CPE\Programing\yolov5-sample\DataSet\Bangkaew-Shiba_Test\bk001.jpg: 640x640 1 Shiba_Inu, 16.0ms
# ...

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

def readFolder(exp):
    for i in os.listdir('runs/detect/'+exp):
        full_path = 'runs/detect/'+exp+'/'+i
        img = mpimg.imread(full_path)
        imgplot = plt.imshow(img)
        plt.show()

# %%
readFolder('exp2')
